# %% [markdown]
# <a href="https://colab.research.google.com/github/ankush2805/EIP/blob/master/Tests5/PersonAttributes.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# mount gdrive and unzip data
from google.colab import drive
drive.mount('/content/gdrive')
# !unzip -q "/content/gdrive/My Drive/hvc_data.zip"
# look for `hvc_annotations.csv` file and `resized` dir
# %ls
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive
# gdrive/  hvc_annotations.csv  resized/  sample_data/

# %%
# %tensorflow_version 1.x

import cv2
import json

import numpy as np
import pandas as pd

from functools import partial
from pathlib import Path 
from tqdm import tqdm

from google.colab.patches import cv2_imshow

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, OneHotEncoder


from keras.applications import VGG16
from keras.layers.core import Dropout
from keras.layers.core import Flatten
from keras.layers.core import Dense
from keras.layers import Input
from keras.models import Model
from keras.optimizers import SGD
from keras.preprocessing.image import ImageDataGenerator
# Out:
# Using TensorFlow backend.

# %%
# load annotations
df = pd.read_csv("hvc_annotations.csv")
del df["filename"] # remove unwanted column
df.head()
# Out:
#    gender imagequality    age  ...        emotion        bodypose     image_path
# 0    male      Average  35-45  ...        Neutral  Front-Frontish  resized/1.jpg
# 1  female      Average  35-45  ...  Angry/Serious  Front-Frontish  resized/2.jpg
# 2    male         Good  45-55  ...        Neutral  Front-Frontish  resized/3.jpg
# 3    male         Good  45-55  ...        Neutral  Front-Frontish  resized/4.jpg
# 4  female         Good  35-45  ...        Neutral  Front-Frontish  resized/5.jpg
#
# [5 rows x 9 columns]

# %%
# one hot encoding of labels

one_hot_df = pd.concat([
    df[["image_path"]],
    pd.get_dummies(df.gender, prefix="gender"),
    pd.get_dummies(df.imagequality, prefix="imagequality"),
    pd.get_dummies(df.age, prefix="age"),
    pd.get_dummies(df.weight, prefix="weight"),
    pd.get_dummies(df.carryingbag, prefix="carryingbag"),
    pd.get_dummies(df.footwear, prefix="footwear"),
    pd.get_dummies(df.emotion, prefix="emotion"),
    pd.get_dummies(df.bodypose, prefix="bodypose"),
], axis = 1)

one_hot_df.head().T
# Out:
#                                                   0  ...              4
# image_path                            resized/1.jpg  ...  resized/5.jpg
# gender_female                                     0  ...              1
# gender_male                                       1  ...              0
# imagequality_Average                              1  ...              0
# imagequality_Bad                                  0  ...              0
# imagequality_Good                                 0  ...              1
# age_15-25                                         0  ...              0
# age_25-35                                         0  ...              0
# age_35-45                                         1  ...              1
# age_45-55                                         0  ...              0
# age_55+                                           0  ...              0
# weight_normal-healthy                             1  ...              0
# weight_over-weight                                0  ...              0
# weight_slightly-overweight                        0  ...              1
# weight_underweight                                0  ...              0
# carryingbag_Daily/Office/Work Bag                 0  ...              0
# carryingbag_Grocery/Home/Plastic Bag              1  ...              0
# carryingbag_None                                  0  ...              1
# footwear_CantSee                                  0  ...              1
# footwear_Fancy                                    0  ...              0
# footwear_Normal                                   1  ...              0
# emotion_Angry/Serious                             0  ...              0
# emotion_Happy                                     0  ...              0
# emotion_Neutral                                   1  ...              1
# emotion_Sad                                       0  ...              0
# bodypose_Back                                     0  ...              0
# bodypose_Front-Frontish                           1  ...              1
# bodypose_Side                                     0  ...              0
#
# [28 rows x 5 columns]

# %%
def get_random_eraser(input_img, p=0.5, s_l=0.02, s_h=0.4, r_1=0.3, r_2=1/0.3, v_l=0, v_h=1, pixel_level=False):
  img_h, img_w, img_c = input_img.shape
  p_1 = np.random.rand()
  if p_1 > p:
    return input_img

  while True:
    s = np.random.uniform(s_l, s_h) * img_h * img_w
    r = np.random.uniform(r_1, r_2)
    w = int(np.sqrt(s / r))
    h = int(np.sqrt(s * r))
    left = np.random.randint(0, img_w)
    top = np.random.randint(0, img_h)

    if left + w <= img_w and top + h <= img_h:
      break

    if pixel_level:
      c = np.random.uniform(v_l, v_h, (h, w, img_c))
    else:
      c = np.random.uniform(v_l, v_h)
    input_img[top:top + h, left:left + w, :] = c
  return input_img

# %%
def augmentor(images):
		'Apply data augmentation'
		sometimes = lambda aug: iaa.Sometimes(0.5, aug)
		seq = iaa.Sequential(
				[
				# apply the following augmenters to most images
				iaa.Fliplr(0.3),  # horizontally flip 50% of all images
				sometimes(iaa.Affine(
					scale={"x": (0.9, 1.1), "y": (0.9, 1.1)},
					# scale images to 80-120% of their size, individually per axis
					translate_percent={"x": (-0.1, 0.1), "y": (-0.1, 0.1)},
					# translate by -20 to +20 percent (per axis)
					rotate=(-10, 10),  # rotate by -45 to +45 degrees
					shear=(-5, 5),  # shear by -16 to +16 degrees
					order=[0, 1],
					# use nearest neighbour or bilinear interpolation (fast)
					cval=(0, 255),  # if mode is constant, use a cval between 0 and 255
					mode=ia.ALL
					# use any of scikit-image's warping modes (see 2nd image from the top for examples)
				)),
				# execute 0 to 5 of the following (less important) augmenters per image
				# don't execute all of them, as that would often be way too strong
				iaa.SomeOf((0, 5),
				           [sometimes(iaa.Superpixels(p_replace=(0, 1.0),
						                                     n_segments=(20, 200))),
					           # convert images into their superpixel representation
					           iaa.OneOf([
							           iaa.GaussianBlur((0, 1.0)),
							           # blur images with a sigma between 0 and 3.0
							           iaa.AverageBlur(k=(3, 5)),
							           # blur image using local means with kernel sizes between 2 and 7
							           iaa.MedianBlur(k=(3, 5)),
							           # blur image using local medians with kernel sizes between 2 and 7
					           ]),
					           iaa.Sharpen(alpha=(0, 1.0), lightness=(0.9, 1.1)),
					           # sharpen images
					           iaa.Emboss(alpha=(0, 1.0), strength=(0, 2.0)),
					           # emboss images
					           # search either for all edges or for directed edges,
					           # blend the result with the original image using a blobby mask
					           iaa.SimplexNoiseAlpha(iaa.OneOf([
							           iaa.EdgeDetect(alpha=(0.5, 1.0)),
							           iaa.DirectedEdgeDetect(alpha=(0.5, 1.0),
							                                  direction=(0.0, 1.0)),
					           ])),
					           iaa.AdditiveGaussianNoise(loc=0,
					                                     scale=(0.0, 0.01 * 255),
					                                     per_channel=0.5),
					           # add gaussian noise to images
					           
					           
					           iaa.Add((-2, 2), per_channel=0.5),
					           # change brightness of images (by -10 to 10 of original value)
					           iaa.AddToHueAndSaturation((-1, 1)),
					           # change hue and saturation
					           # either change the brightness of the whole image (sometimes
					           # per channel) or change the brightness of subareas
					           iaa.OneOf([
							           iaa.Multiply((0.9, 1.1), per_channel=0.5),
							           iaa.FrequencyNoiseAlpha(
									           exponent=(-1, 0),
									           first=iaa.Multiply((0.9, 1.1),
									                              per_channel=True),
									           second=iaa.ContrastNormalization(
											           (0.9, 1.1))
							           )
					           ]),
					           sometimes(iaa.ElasticTransformation(alpha=(0.5, 3.5),
					                                               sigma=0.25)),
					           # move pixels locally around (with random strengths)
					           sometimes(iaa.PiecewiseAffine(scale=(0.01, 0.05))),
					           # sometimes move parts of the image around
					           sometimes(iaa.PerspectiveTransform(scale=(0.01, 0.1)))
				           ],
				           random_order=True
				           )
				],
				random_order=True
		)
		return seq.augment_images(images)

# %%
import cv2
from albumentations import (
    Compose, HorizontalFlip, CLAHE, HueSaturationValue,
    RandomBrightness, RandomContrast, RandomGamma,
    ToFloat, ShiftScaleRotate, Normalize
)
AUGMENTATIONS_NORMALIZE = Compose([
    ToFloat(max_value=255)
])

# %%
trainAug = ImageDataGenerator(
	rotation_range=30,
	zoom_range=0.15,
	width_shift_range=0.2,
	height_shift_range=0.2,
	shear_range=0.15,
	horizontal_flip=True,
	fill_mode="nearest")

# %%
import keras
import numpy as np
import imgaug as ia
import imgaug.augmenters as iaa

ia.seed(1)
# Label columns per attribute
_gender_cols_ = [col for col in one_hot_df.columns if col.startswith("gender")]
_imagequality_cols_ = [col for col in one_hot_df.columns if col.startswith("imagequality")]
_age_cols_ = [col for col in one_hot_df.columns if col.startswith("age")]
_weight_cols_ = [col for col in one_hot_df.columns if col.startswith("weight")]
_carryingbag_cols_ = [col for col in one_hot_df.columns if col.startswith("carryingbag")]
_footwear_cols_ = [col for col in one_hot_df.columns if col.startswith("footwear")]
_emotion_cols_ = [col for col in one_hot_df.columns if col.startswith("emotion")]
_bodypose_cols_ = [col for col in one_hot_df.columns if col.startswith("bodypose")]

class PersonDataGenerator(keras.utils.Sequence):
    """Ground truth data generator"""

    
    def __init__(self, df, batch_size=32, shuffle=True,augmentation=None):
        self.df = df
        self.batch_size=batch_size
        self.shuffle = shuffle
        self.on_epoch_end()
        self.augment = augmentation

    def __len__(self):
        return int(np.floor(self.df.shape[0] / self.batch_size))

    def __getitem__(self, index):
        """fetch batched images and targets"""
        batch_slice = slice(index * self.batch_size, (index + 1) * self.batch_size)
        items = self.df.iloc[batch_slice]
        image = np.stack([cv2.imread(item["image_path"]) for _, item in items.iterrows()])
        #image = np.stack([AUGMENTATIONS_NORMALIZE(image=img)["image"] for img in image])
        #if self.augment is not None:
        #  self.augment.fit(image)
        #  image = self.augment.flow(image, shuffle=False).next()
        #  image = np.stack([get_random_eraser(img) for img in image])
        if self.batch_size ==32:
          image = augmentor(image)
          image = np.stack([get_random_eraser(img) for img in image])
        image = np.stack([AUGMENTATIONS_NORMALIZE(image=img)["image"] for img in image])
        target = {
            "gender_output": items[_gender_cols_].values,
            "image_quality_output": items[_imagequality_cols_].values,
            "age_output": items[_age_cols_].values,
            "weight_output": items[_weight_cols_].values,
            "bag_output": items[_carryingbag_cols_].values,
            "pose_output": items[_bodypose_cols_].values,
            "footwear_output": items[_footwear_cols_].values,
            "emotion_output": items[_emotion_cols_].values,
        }
        return image, target

    def on_epoch_end(self):
        """Updates indexes after each epoch"""
        if self.shuffle == True:
            self.df = self.df.sample(frac=1).reset_index(drop=True)

# %%
from sklearn.model_selection import train_test_split
train_df, val_df = train_test_split(one_hot_df, test_size=0.15, random_state=2)
train_df.shape, val_df.shape
# Out:
# ((11537, 28), (2036, 28))

# %%
train_df.head()
# Out:
#               image_path  gender_female  ...  bodypose_Front-Frontish  bodypose_Side
# 12579  resized/12581.jpg              1  ...                        1              0
# 7448    resized/7449.jpg              0  ...                        0              1
# 7260    resized/7261.jpg              0  ...                        1              0
# 10955  resized/10957.jpg              0  ...                        1              0
# 7360    resized/7361.jpg              1  ...                        1              0
#
# [5 rows x 28 columns]

# %%
# create train and validation data generators
train_gen = PersonDataGenerator(train_df, batch_size=32,shuffle=True, augmentation=trainAug)
valid_gen = PersonDataGenerator(val_df, batch_size=64, shuffle=False)

# %%
# get number of output units from data
images, targets = next(iter(train_gen))
num_units = { k.split("_output")[0]:v.shape[1] for k, v in targets.items()}
num_units
# Out:
# {'age': 5,
#  'bag': 3,
#  'emotion': 4,
#  'footwear': 3,
#  'gender': 2,
#  'image_quality': 3,
#  'pose': 3,
#  'weight': 4}

# %%
def lr_schedule(epoch):
    """Learning Rate Schedule

    Learning rate is scheduled to be reduced after 80, 120, 160, 180 epochs.
    Called automatically every epoch as part of callbacks during training.

    # Arguments
        epoch (int): The number of epochs

    # Returns
        lr (float32): learning rate
    """
    lr = 0.001
    if epoch > 95:
        lr = 0.000001
    if epoch > 80:
        lr = 0.00005
    elif epoch > 60:
        lr = 0.0001
    elif epoch > 40:
        lr = 0.0005
    elif epoch > 20:
        lr = 0.001
    print('Learning rate: ', lr)
    return lr

# %%
from keras.applications import InceptionV3, Xception, DenseNet121, DenseNet201, ResNet152V2
from keras.layers import GlobalAveragePooling2D


backbone = ResNet152V2(
    weights=None, 
    include_top=False, 
    input_tensor=Input(shape=(224, 224, 3))
)

neck = backbone.output
neck = GlobalAveragePooling2D()(neck)
#neck = Flatten(name="flatten")(neck)
neck = Dense(512, activation="relu")(neck)

def build_dense_tower(in_layer):
    neck = Dense(128, activation="relu")(in_layer)
    neck = Dropout(0.1)(in_layer)
    neck = Dense(128, activation="relu")(neck)
    neck = Dropout(0.1)(in_layer)
    neck = Dense(128, activation="relu")(neck)
    neck = Dropout(0.1)(in_layer)
    neck = Dense(128, activation="relu")(neck)
    neck = Dropout(0.1)(in_layer)
    #neck = Dense(128, activation="relu")(neck)
    return neck

def build_tower(in_layer):
    neck = Dropout(0.2)(in_layer)
    neck = Dense(128, activation="relu")(neck)
    neck = Dropout(0.3)(in_layer)
    neck = Dense(128, activation="relu")(neck)
    #neck = Dense(128, activation="relu")(neck)
    #neck = Dense(128, activation="relu")(neck)
    #neck = Dense(128, activation="relu")(neck)
    return neck


def build_head(name, in_layer):
    return Dense(
        num_units[name], activation="softmax", name=f"{name}_output"
    )(in_layer)

# heads
gender = build_head("gender", build_dense_tower(neck))
image_quality = build_head("image_quality", build_dense_tower(neck))
age = build_head("age", build_tower(neck))
weight = build_head("weight", build_tower(neck))
bag = build_head("bag", build_dense_tower(neck))
footwear = build_head("footwear", build_dense_tower(neck))
emotion = build_head("emotion", build_tower(neck))
pose = build_head("pose", build_dense_tower(neck))


#model = Model(
#    inputs=backbone.input, outputs=[gender, image_quality, age, weight, bag, footwear, pose, emotion])
from keras.models import load_model
model = load_model('/content/gdrive/My Drive/person_attributes3.hdf5')
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:66: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:541: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4432: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4267: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:190: The name tf.get_default_session is deprecated. Please use tf.compat.v1.get_default_session instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:197: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:203: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:207: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:216: The name tf.is_variable_initialized is deprecated. Please use tf.compat.v1.is_variable_initialized instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:223: The name tf.variables_initializer is deprecated. Please use tf.compat.v1.variables_initializer instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:2041: The name tf.nn.fused_batch_norm is deprecated. Please use tf.compat.v1.nn.fused_batch_norm instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:148: The name tf.placeholder_with_default is deprecated. Please use tf.compat.v1.placeholder_with_default instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:3733: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/optimizers.py:793: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:3576: The name tf.log is deprecated. Please use tf.math.log instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/ops/math_grad.py:1424: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:1033: The name tf.assign_add is deprecated. Please use tf.compat.v1.assign_add instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:1020: The name tf.assign is deprecated. Please use tf.compat.v1.assign instead.

# %%
# losses = {
# 	"gender_output": "binary_crossentropy",
# 	"image_quality_output": "categorical_crossentropy",
# 	"age_output": "categorical_crossentropy",
# 	"weight_output": "categorical_crossentropy",

# }
# loss_weights = {"gender_output": 1.0, "image_quality_output": 1.0, "age_output": 1.0}
from keras.optimizers import Adam
opt = Adam(lr=lr_schedule(0))
model.compile(
    optimizer=opt,
    loss="categorical_crossentropy", 
    # loss_weights=loss_weights, 
    metrics=["accuracy"]
)
# Out:
# Learning rate:  0.01

# %%
# model.fit(X_train, y_train, validation_data=(X_valid, y_valid), batch_size=32, epochs=10)

# %%
import os
from keras.callbacks import ModelCheckpoint, ReduceLROnPlateau
#drive.mount('/content/gdrive')
filepath = '/content/gdrive/My Drive/person_attributes3.hdf5'

checkpoint = ModelCheckpoint(filepath=filepath,
                             verbose=1,save_weights_only=False,
                             period =10)

callbacks = [checkpoint]
model.fit_generator(
    generator=train_gen,
    validation_data=valid_gen,
    use_multiprocessing=True,
    workers=6, 
    epochs=100,
    verbose=1,callbacks=callbacks
)
# Out:
# Epoch 1/100
# 359/360 [============================>.] - ETA: 0s - loss: 5.6262 - gender_output_loss: 0.2351 - image_quality_output_loss: 0.8634 - age_output_loss: 1.1705 - weight_output_loss: 0.7946 - bag_output_loss: 0.6592 - footwear_output_loss: 0.7142 - pose_output_loss: 0.3409 - emotion_output_loss: 0.8483 - gender_output_acc: 0.9055 - image_quality_output_acc: 0.5917 - age_output_acc: 0.4834 - weight_output_acc: 0.6791 - bag_output_acc: 0.7449 - footwear_output_acc: 0.6862 - pose_output_acc: 0.8756 - emotion_output_acc: 0.7112
#
# 360/360 [==============================] - 352s 978ms/step - loss: 5.6274 - gender_output_loss: 0.2352 - image_quality_output_loss: 0.8641 - age_output_loss: 1.1705 - weight_output_loss: 0.7954 - bag_output_loss: 0.6594 - footwear_output_loss: 0.7141 - pose_output_loss: 0.3410 - emotion_output_loss: 0.8478 - gender_output_acc: 0.9054 - image_quality_output_acc: 0.5912 - age_output_acc: 0.4832 - weight_output_acc: 0.6791 - bag_output_acc: 0.7446 - footwear_output_acc: 0.6862 - pose_output_acc: 0.8757 - emotion_output_acc: 0.7115 - val_loss: 6.5465 - val_gender_output_loss: 0.2819 - val_image_quality_output_loss: 0.9383 - val_age_output_loss: 1.2972 - val_weight_output_loss: 1.0203 - val_bag_output_loss: 0.8784 - val_footwear_output_loss: 0.8283 - val_pose_output_loss: 0.4579 - val_emotion_output_loss: 0.8442 - val_gender_output_acc: 0.9002 - val_image_quality_output_acc: 0.5509 - val_age_output_acc: 0.4420 - val_weight_output_acc: 0.6240 - val_bag_output_acc: 0.6855 - val_footwear_output_acc: 0.6557 - val_pose_output_acc: 0.8659 - val_emotion_output_acc: 0.7213
# Epoch 2/100
# 360/360 [==============================] - 289s 801ms/step - loss: 5.5972 - gender_output_loss: 0.2376 - image_quality_output_loss: 0.8528 - age_output_loss: 1.1556 - weight_output_loss: 0.7909 - bag_output_loss: 0.6508 - footwear_output_loss: 0.7023 - pose_output_loss: 0.3633 - emotion_output_loss: 0.8438 - gender_output_acc: 0.9037 - image_quality_output_acc: 0.5990 - age_output_acc: 0.4822 - weight_output_acc: 0.6794 - bag_output_acc: 0.7509 - footwear_output_acc: 0.6939 - pose_output_acc: 0.8655 - emotion_output_acc: 0.7116 - val_loss: 6.4782 - val_gender_output_loss: 0.3170 - val_image_quality_output_loss: 0.9921 - val_age_output_loss: 1.3009 - val_weight_output_loss: 0.9126 - val_bag_output_loss: 0.8042 - val_footwear_output_loss: 0.7840 - val_pose_output_loss: 0.5176 - val_emotion_output_loss: 0.8499 - val_gender_output_acc: 0.8982 - val_image_quality_output_acc: 0.5171 - val_age_output_acc: 0.4536 - val_weight_output_acc: 0.6426 - val_bag_output_acc: 0.6981 - val_footwear_output_acc: 0.6648 - val_pose_output_acc: 0.8750 - val_emotion_output_acc: 0.7228
# Epoch 3/100
# 360/360 [==============================] - 285s 792ms/step - loss: 5.4138 - gender_output_loss: 0.2019 - image_quality_output_loss: 0.8396 - age_output_loss: 1.1298 - weight_output_loss: 0.7619 - bag_output_loss: 0.6329 - footwear_output_loss: 0.6931 - pose_output_loss: 0.3121 - emotion_output_loss: 0.8425 - gender_output_acc: 0.9161 - image_quality_output_acc: 0.6073 - age_output_acc: 0.5034 - weight_output_acc: 0.6962 - bag_output_acc: 0.7567 - footwear_output_acc: 0.6954 - pose_output_acc: 0.8881 - emotion_output_acc: 0.7120 - val_loss: 6.3696 - val_gender_output_loss: 0.2996 - val_image_quality_output_loss: 0.9591 - val_age_output_loss: 1.2814 - val_weight_output_loss: 0.9232 - val_bag_output_loss: 0.8138 - val_footwear_output_loss: 0.7961 - val_pose_output_loss: 0.4454 - val_emotion_output_loss: 0.8511 - val_gender_output_acc: 0.9002 - val_image_quality_output_acc: 0.5514 - val_age_output_acc: 0.4521 - val_weight_output_acc: 0.6386 - val_bag_output_acc: 0.7046 - val_footwear_output_acc: 0.6618 - val_pose_output_acc: 0.8604 - val_emotion_output_acc: 0.7228
# Epoch 4/100
# 359/360 [============================>.] - ETA: 0s - loss: 6.0157 - gender_output_loss: 0.2858 - image_quality_output_loss: 0.9031 - age_output_loss: 1.2104 - weight_output_loss: 0.8512 - bag_output_loss: 0.7076 - footwear_output_loss: 0.7717 - pose_output_loss: 0.4252 - emotion_output_loss: 0.8607 - gender_output_acc: 0.8852 - image_quality_output_acc: 0.5769 - age_output_acc: 0.4713 - weight_output_acc: 0.6678 - bag_output_acc: 0.7257 - footwear_output_acc: 0.6694 - pose_output_acc: 0.8370 - emotion_output_acc: 0.7093Epoch 4/100
# 360/360 [==============================] - 282s 784ms/step - loss: 6.0152 - gender_output_loss: 0.2854 - image_quality_output_loss: 0.9032 - age_output_loss: 1.2108 - weight_output_loss: 0.8512 - bag_output_loss: 0.7078 - footwear_output_loss: 0.7715 - pose_output_loss: 0.4256 - emotion_output_loss: 0.8596 - gender_output_acc: 0.8854 - image_quality_output_acc: 0.5767 - age_output_acc: 0.4710 - weight_output_acc: 0.6678 - bag_output_acc: 0.7256 - footwear_output_acc: 0.6694 - pose_output_acc: 0.8370 - emotion_output_acc: 0.7099 - val_loss: 6.6544 - val_gender_output_loss: 0.3499 - val_image_quality_output_loss: 0.9605 - val_age_output_loss: 1.2928 - val_weight_output_loss: 0.9235 - val_bag_output_loss: 0.9385 - val_footwear_output_loss: 0.7930 - val_pose_output_loss: 0.5612 - val_emotion_output_loss: 0.8349 - val_gender_output_acc: 0.8821 - val_image_quality_output_acc: 0.5343 - val_age_output_acc: 0.4385 - val_weight_output_acc: 0.6426 - val_bag_output_acc: 0.6724 - val_footwear_output_acc: 0.6673 - val_pose_output_acc: 0.8574 - val_emotion_output_acc: 0.7223
# Epoch 5/100
# 359/360 [============================>.] - ETA: 0s - loss: 5.8626 - gender_output_loss: 0.3032 - image_quality_output_loss: 0.8838 - age_output_loss: 1.1928 - weight_output_loss: 0.8347 - bag_output_loss: 0.6870 - footwear_output_loss: 0.7261 - pose_output_loss: 0.3805 - emotion_output_loss: 0.8545 - gender_output_acc: 0.8651 - image_quality_output_acc: 0.5829 - age_output_acc: 0.4760 - weight_output_acc: 0.6675 - bag_output_acc: 0.7307 - footwear_output_acc: 0.6782 - pose_output_acc: 0.8576 - emotion_output_acc: 0.7117Epoch 5/100
# 360/360 [==============================] - 290s 807ms/step - loss: 5.8621 - gender_output_loss: 0.3030 - image_quality_output_loss: 0.8838 - age_output_loss: 1.1928 - weight_output_loss: 0.8343 - bag_output_loss: 0.6868 - footwear_output_loss: 0.7259 - pose_output_loss: 0.3807 - emotion_output_loss: 0.8548 - gender_output_acc: 0.8652 - image_quality_output_acc: 0.5828 - age_output_acc: 0.4757 - weight_output_acc: 0.6677 - bag_output_acc: 0.7309 - footwear_output_acc: 0.6784 - pose_output_acc: 0.8574 - emotion_output_acc: 0.7115 - val_loss: 6.3505 - val_gender_output_loss: 0.2983 - val_image_quality_output_loss: 1.0303 - val_age_output_loss: 1.2753 - val_weight_output_loss: 0.8994 - val_bag_output_loss: 0.7970 - val_footwear_output_loss: 0.8279 - val_pose_output_loss: 0.3793 - val_emotion_output_loss: 0.8428 - val_gender_output_acc: 0.8911 - val_image_quality_output_acc: 0.5161 - val_age_output_acc: 0.4330 - val_weight_output_acc: 0.6411 - val_bag_output_acc: 0.6764 - val_footwear_output_acc: 0.6396 - val_pose_output_acc: 0.8720 - val_emotion_output_acc: 0.7182
# Epoch 6/100
# 360/360 [==============================] - 292s 810ms/step - loss: 5.4644 - gender_output_loss: 0.2108 - image_quality_output_loss: 0.8519 - age_output_loss: 1.1384 - weight_output_loss: 0.7870 - bag_output_loss: 0.6305 - footwear_output_loss: 0.6896 - pose_output_loss: 0.3160 - emotion_output_loss: 0.8402 - gender_output_acc: 0.9143 - image_quality_output_acc: 0.6018 - age_output_acc: 0.4974 - weight_output_acc: 0.6857 - bag_output_acc: 0.7575 - footwear_output_acc: 0.6955 - pose_output_acc: 0.8819 - emotion_output_acc: 0.7128 - val_loss: 6.7828 - val_gender_output_loss: 0.3132 - val_image_quality_output_loss: 0.9650 - val_age_output_loss: 1.4553 - val_weight_output_loss: 1.0106 - val_bag_output_loss: 0.8493 - val_footwear_output_loss: 0.9109 - val_pose_output_loss: 0.4276 - val_emotion_output_loss: 0.8509 - val_gender_output_acc: 0.8831 - val_image_quality_output_acc: 0.5539 - val_age_output_acc: 0.4042 - val_weight_output_acc: 0.6119 - val_bag_output_acc: 0.6442 - val_footwear_output_acc: 0.6008 - val_pose_output_acc: 0.8473 - val_emotion_output_acc: 0.7213
# Epoch 7/100
# 360/360 [==============================] - 291s 810ms/step - loss: 5.4012 - gender_output_loss: 0.2084 - image_quality_output_loss: 0.8395 - age_output_loss: 1.1302 - weight_output_loss: 0.7742 - bag_output_loss: 0.6355 - footwear_output_loss: 0.6850 - pose_output_loss: 0.2891 - emotion_output_loss: 0.8393 - gender_output_acc: 0.9159 - image_quality_output_acc: 0.6027 - age_output_acc: 0.5006 - weight_output_acc: 0.6906 - bag_output_acc: 0.7556 - footwear_output_acc: 0.6953 - pose_output_acc: 0.8910 - emotion_output_acc: 0.7135 - val_loss: 6.4232 - val_gender_output_loss: 0.3068 - val_image_quality_output_loss: 0.9651 - val_age_output_loss: 1.2915 - val_weight_output_loss: 0.9065 - val_bag_output_loss: 0.9301 - val_footwear_output_loss: 0.7910 - val_pose_output_loss: 0.3964 - val_emotion_output_loss: 0.8359 - val_gender_output_acc: 0.8931 - val_image_quality_output_acc: 0.5595 - val_age_output_acc: 0.4446 - val_weight_output_acc: 0.6532 - val_bag_output_acc: 0.6830 - val_footwear_output_acc: 0.6689 - val_pose_output_acc: 0.8755 - val_emotion_output_acc: 0.7233
# Epoch 8/100
# 360/360 [==============================] - 280s 779ms/step - loss: 5.1876 - gender_output_loss: 0.1864 - image_quality_output_loss: 0.8115 - age_output_loss: 1.0953 - weight_output_loss: 0.7277 - bag_output_loss: 0.6018 - footwear_output_loss: 0.6691 - pose_output_loss: 0.2663 - emotion_output_loss: 0.8295 - gender_output_acc: 0.9259 - image_quality_output_acc: 0.6215 - age_output_acc: 0.5182 - weight_output_acc: 0.7067 - bag_output_acc: 0.7723 - footwear_output_acc: 0.7084 - pose_output_acc: 0.9018 - emotion_output_acc: 0.7154 - val_loss: 6.4531 - val_gender_output_loss: 0.2917 - val_image_quality_output_loss: 0.9618 - val_age_output_loss: 1.3143 - val_weight_output_loss: 0.9471 - val_bag_output_loss: 0.8786 - val_footwear_output_loss: 0.8021 - val_pose_output_loss: 0.4191 - val_emotion_output_loss: 0.8383 - val_gender_output_acc: 0.9052 - val_image_quality_output_acc: 0.5595 - val_age_output_acc: 0.4461 - val_weight_output_acc: 0.6532 - val_bag_output_acc: 0.6961 - val_footwear_output_acc: 0.6527 - val_pose_output_acc: 0.8735 - val_emotion_output_acc: 0.7213
# Epoch 9/100
# 360/360 [==============================] - 282s 783ms/step - loss: 5.1082 - gender_output_loss: 0.1765 - image_quality_output_loss: 0.8099 - age_output_loss: 1.0866 - weight_output_loss: 0.7159 - bag_output_loss: 0.5886 - footwear_output_loss: 0.6486 - pose_output_loss: 0.2529 - emotion_output_loss: 0.8293 - gender_output_acc: 0.9337 - image_quality_output_acc: 0.6230 - age_output_acc: 0.5172 - weight_output_acc: 0.7089 - bag_output_acc: 0.7780 - footwear_output_acc: 0.7150 - pose_output_acc: 0.9077 - emotion_output_acc: 0.7158 - val_loss: 6.5477 - val_gender_output_loss: 0.2957 - val_image_quality_output_loss: 1.0151 - val_age_output_loss: 1.2907 - val_weight_output_loss: 0.9345 - val_bag_output_loss: 0.8914 - val_footwear_output_loss: 0.8690 - val_pose_output_loss: 0.4076 - val_emotion_output_loss: 0.8437 - val_gender_output_acc: 0.9032 - val_image_quality_output_acc: 0.5257 - val_age_output_acc: 0.4435 - val_weight_output_acc: 0.6295 - val_bag_output_acc: 0.7006 - val_footwear_output_acc: 0.6714 - val_pose_output_acc: 0.8725 - val_emotion_output_acc: 0.7233
# Epoch 10/100
# 360/360 [==============================] - 279s 776ms/step - loss: 5.0637 - gender_output_loss: 0.1757 - image_quality_output_loss: 0.8000 - age_output_loss: 1.0687 - weight_output_loss: 0.7238 - bag_output_loss: 0.5740 - footwear_output_loss: 0.6491 - pose_output_loss: 0.2465 - emotion_output_loss: 0.8261 - gender_output_acc: 0.9321 - image_quality_output_acc: 0.6312 - age_output_acc: 0.5340 - weight_output_acc: 0.7121 - bag_output_acc: 0.7806 - footwear_output_acc: 0.7167 - pose_output_acc: 0.9111 - emotion_output_acc: 0.7143 - val_loss: 6.5931 - val_gender_output_loss: 0.3737 - val_image_quality_output_loss: 1.0490 - val_age_output_loss: 1.3091 - val_weight_output_loss: 0.9672 - val_bag_output_loss: 0.8498 - val_footwear_output_loss: 0.8132 - val_pose_output_loss: 0.3993 - val_emotion_output_loss: 0.8316 - val_gender_output_acc: 0.8962 - val_image_quality_output_acc: 0.5136 - val_age_output_acc: 0.4506 - val_weight_output_acc: 0.6522 - val_bag_output_acc: 0.7026 - val_footwear_output_acc: 0.6744 - val_pose_output_acc: 0.8780 - val_emotion_output_acc: 0.7238
#
# Epoch 00010: saving model to /content/gdrive/My Drive/person_attributes3.hdf5
# Epoch 11/100
# 359/360 [============================>.] - ETA: 0s - loss: 5.6955 - gender_output_loss: 0.2586 - image_quality_output_loss: 0.8613 - age_output_loss: 1.1826 - weight_output_loss: 0.7968 - bag_output_loss: 0.6814 - footwear_output_loss: 0.7210 - pose_output_loss: 0.3491 - emotion_output_loss: 0.8446 - gender_output_acc: 0.8945 - image_quality_output_acc: 0.6006 - age_output_acc: 0.4830 - weight_output_acc: 0.6845 - bag_output_acc: 0.7294 - footwear_output_acc: 0.6790 - pose_output_acc: 0.8679 - emotion_output_acc: 0.7129
# Epoch 00010: saving model to /content/gdrive/My Drive/person_attributes3.hdf5
# 360/360 [==============================] - 281s 782ms/step - loss: 5.6956 - gender_output_loss: 0.2589 - image_quality_output_loss: 0.8610 - age_output_loss: 1.1828 - weight_output_loss: 0.7966 - bag_output_loss: 0.6811 - footwear_output_loss: 0.7209 - pose_output_loss: 0.3490 - emotion_output_loss: 0.8453 - gender_output_acc: 0.8943 - image_quality_output_acc: 0.6009 - age_output_acc: 0.4831 - weight_output_acc: 0.6845 - bag_output_acc: 0.7294 - footwear_output_acc: 0.6793 - pose_output_acc: 0.8679 - emotion_output_acc: 0.7127 - val_loss: 6.3957 - val_gender_output_loss: 0.2218 - val_image_quality_output_loss: 0.9923 - val_age_output_loss: 1.3090 - val_weight_output_loss: 0.9239 - val_bag_output_loss: 0.9624 - val_footwear_output_loss: 0.7667 - val_pose_output_loss: 0.3821 - val_emotion_output_loss: 0.8376 - val_gender_output_acc: 0.9234 - val_image_quality_output_acc: 0.5373 - val_age_output_acc: 0.4486 - val_weight_output_acc: 0.6552 - val_bag_output_acc: 0.6724 - val_footwear_output_acc: 0.6704 - val_pose_output_acc: 0.8826 - val_emotion_output_acc: 0.7218
# Epoch 12/100
# 360/360 [==============================] - 286s 795ms/step - loss: 5.1494 - gender_output_loss: 0.1813 - image_quality_output_loss: 0.8063 - age_output_loss: 1.0935 - weight_output_loss: 0.7190 - bag_output_loss: 0.5914 - footwear_output_loss: 0.6575 - pose_output_loss: 0.2707 - emotion_output_loss: 0.8297 - gender_output_acc: 0.9275 - image_quality_output_acc: 0.6236 - age_output_acc: 0.5167 - weight_output_acc: 0.7117 - bag_output_acc: 0.7785 - footwear_output_acc: 0.7140 - pose_output_acc: 0.8994 - emotion_output_acc: 0.7158 - val_loss: 6.6698 - val_gender_output_loss: 0.3429 - val_image_quality_output_loss: 1.0347 - val_age_output_loss: 1.2764 - val_weight_output_loss: 1.0360 - val_bag_output_loss: 0.8574 - val_footwear_output_loss: 0.8782 - val_pose_output_loss: 0.4048 - val_emotion_output_loss: 0.8394 - val_gender_output_acc: 0.8841 - val_image_quality_output_acc: 0.5262 - val_age_output_acc: 0.4536 - val_weight_output_acc: 0.6401 - val_bag_output_acc: 0.6855 - val_footwear_output_acc: 0.6552 - val_pose_output_acc: 0.8659 - val_emotion_output_acc: 0.7203
# Epoch 13/100
# 360/360 [==============================] - 280s 778ms/step - loss: 5.0588 - gender_output_loss: 0.1600 - image_quality_output_loss: 0.8033 - age_output_loss: 1.0771 - weight_output_loss: 0.7058 - bag_output_loss: 0.5692 - footwear_output_loss: 0.6564 - pose_output_loss: 0.2624 - emotion_output_loss: 0.8247 - gender_output_acc: 0.9373 - image_quality_output_acc: 0.6267 - age_output_acc: 0.5293 - weight_output_acc: 0.7161 - bag_output_acc: 0.7859 - footwear_output_acc: 0.7137 - pose_output_acc: 0.9040 - emotion_output_acc: 0.7174 - val_loss: 6.5770 - val_gender_output_loss: 0.2568 - val_image_quality_output_loss: 1.0597 - val_age_output_loss: 1.3066 - val_weight_output_loss: 0.9647 - val_bag_output_loss: 0.8738 - val_footwear_output_loss: 0.8203 - val_pose_output_loss: 0.4569 - val_emotion_output_loss: 0.8381 - val_gender_output_acc: 0.9229 - val_image_quality_output_acc: 0.5328 - val_age_output_acc: 0.4572 - val_weight_output_acc: 0.6442 - val_bag_output_acc: 0.6930 - val_footwear_output_acc: 0.6588 - val_pose_output_acc: 0.8795 - val_emotion_output_acc: 0.7218
# Epoch 14/100
# 360/360 [==============================] - 284s 789ms/step - loss: 5.4588 - gender_output_loss: 0.2457 - image_quality_output_loss: 0.8370 - age_output_loss: 1.1377 - weight_output_loss: 0.7839 - bag_output_loss: 0.6192 - footwear_output_loss: 0.6838 - pose_output_loss: 0.3138 - emotion_output_loss: 0.8376 - gender_output_acc: 0.9014 - image_quality_output_acc: 0.6086 - age_output_acc: 0.4948 - weight_output_acc: 0.6838 - bag_output_acc: 0.7634 - footwear_output_acc: 0.6992 - pose_output_acc: 0.8835 - emotion_output_acc: 0.7147 - val_loss: 6.5674 - val_gender_output_loss: 0.2964 - val_image_quality_output_loss: 1.0435 - val_age_output_loss: 1.3086 - val_weight_output_loss: 0.9507 - val_bag_output_loss: 0.8700 - val_footwear_output_loss: 0.8129 - val_pose_output_loss: 0.4293 - val_emotion_output_loss: 0.8559 - val_gender_output_acc: 0.8952 - val_image_quality_output_acc: 0.5444 - val_age_output_acc: 0.4441 - val_weight_output_acc: 0.6416 - val_bag_output_acc: 0.6774 - val_footwear_output_acc: 0.6442 - val_pose_output_acc: 0.8679 - val_emotion_output_acc: 0.7112
# Epoch 15/100
# 359/360 [============================>.] - ETA: 0s - loss: 5.6052 - gender_output_loss: 0.2337 - image_quality_output_loss: 0.8479 - age_output_loss: 1.1488 - weight_output_loss: 0.7793 - bag_output_loss: 0.6489 - footwear_output_loss: 0.7007 - pose_output_loss: 0.3987 - emotion_output_loss: 0.8473 - gender_output_acc: 0.9013 - image_quality_output_acc: 0.6079 - age_output_acc: 0.4963 - weight_output_acc: 0.6904 - bag_output_acc: 0.7482 - footwear_output_acc: 0.6931 - pose_output_acc: 0.8464 - emotion_output_acc: 0.7127Epoch 15/100
# 360/360 [==============================] - 282s 784ms/step - loss: 5.6052 - gender_output_loss: 0.2337 - image_quality_output_loss: 0.8479 - age_output_loss: 1.1487 - weight_output_loss: 0.7796 - bag_output_loss: 0.6489 - footwear_output_loss: 0.7005 - pose_output_loss: 0.3986 - emotion_output_loss: 0.8474 - gender_output_acc: 0.9013 - image_quality_output_acc: 0.6079 - age_output_acc: 0.4964 - weight_output_acc: 0.6901 - bag_output_acc: 0.7482 - footwear_output_acc: 0.6932 - pose_output_acc: 0.8465 - emotion_output_acc: 0.7126 - val_loss: 6.4005 - val_gender_output_loss: 0.2795 - val_image_quality_output_loss: 1.0365 - val_age_output_loss: 1.2997 - val_weight_output_loss: 0.9170 - val_bag_output_loss: 0.7834 - val_footwear_output_loss: 0.8042 - val_pose_output_loss: 0.4366 - val_emotion_output_loss: 0.8435 - val_gender_output_acc: 0.9068 - val_image_quality_output_acc: 0.5358 - val_age_output_acc: 0.4506 - val_weight_output_acc: 0.6532 - val_bag_output_acc: 0.6799 - val_footwear_output_acc: 0.6497 - val_pose_output_acc: 0.8347 - val_emotion_output_acc: 0.7228
# Epoch 16/100
# 359/360 [============================>.] - ETA: 0s - loss: 5.3479 - gender_output_loss: 0.1956 - image_quality_output_loss: 0.8308 - age_output_loss: 1.1123 - weight_output_loss: 0.7495 - bag_output_loss: 0.6176 - footwear_output_loss: 0.6818 - pose_output_loss: 0.3269 - emotion_output_loss: 0.8333 - gender_output_acc: 0.9227 - image_quality_output_acc: 0.6150 - age_output_acc: 0.5084 - weight_output_acc: 0.6993 - bag_output_acc: 0.7602 - footwear_output_acc: 0.6986 - pose_output_acc: 0.8733 - emotion_output_acc: 0.7134Epoch 16/100
# 360/360 [==============================] - 283s 787ms/step - loss: 5.3479 - gender_output_loss: 0.1956 - image_quality_output_loss: 0.8309 - age_output_loss: 1.1123 - weight_output_loss: 0.7496 - bag_output_loss: 0.6179 - footwear_output_loss: 0.6815 - pose_output_loss: 0.3265 - emotion_output_loss: 0.8336 - gender_output_acc: 0.9226 - image_quality_output_acc: 0.6149 - age_output_acc: 0.5083 - weight_output_acc: 0.6991 - bag_output_acc: 0.7599 - footwear_output_acc: 0.6987 - pose_output_acc: 0.8734 - emotion_output_acc: 0.7134 - val_loss: 6.3552 - val_gender_output_loss: 0.2759 - val_image_quality_output_loss: 0.9526 - val_age_output_loss: 1.2972 - val_weight_output_loss: 0.9884 - val_bag_output_loss: 0.8293 - val_footwear_output_loss: 0.7749 - val_pose_output_loss: 0.3978 - val_emotion_output_loss: 0.8390 - val_gender_output_acc: 0.9042 - val_image_quality_output_acc: 0.5600 - val_age_output_acc: 0.4456 - val_weight_output_acc: 0.6426 - val_bag_output_acc: 0.6991 - val_footwear_output_acc: 0.6714 - val_pose_output_acc: 0.8725 - val_emotion_output_acc: 0.7228
# Epoch 17/100
# 360/360 [==============================] - 283s 786ms/step - loss: 5.1406 - gender_output_loss: 0.1756 - image_quality_output_loss: 0.8052 - age_output_loss: 1.0838 - weight_output_loss: 0.7188 - bag_output_loss: 0.5943 - footwear_output_loss: 0.6523 - pose_output_loss: 0.2832 - emotion_output_loss: 0.8275 - gender_output_acc: 0.9280 - image_quality_output_acc: 0.6284 - age_output_acc: 0.5265 - weight_output_acc: 0.7149 - bag_output_acc: 0.7723 - footwear_output_acc: 0.7181 - pose_output_acc: 0.8925 - emotion_output_acc: 0.7127 - val_loss: 6.4221 - val_gender_output_loss: 0.2781 - val_image_quality_output_loss: 0.9730 - val_age_output_loss: 1.2877 - val_weight_output_loss: 0.9217 - val_bag_output_loss: 0.8351 - val_footwear_output_loss: 0.7983 - val_pose_output_loss: 0.4765 - val_emotion_output_loss: 0.8517 - val_gender_output_acc: 0.9088 - val_image_quality_output_acc: 0.5549 - val_age_output_acc: 0.4435 - val_weight_output_acc: 0.6527 - val_bag_output_acc: 0.6734 - val_footwear_output_acc: 0.6704 - val_pose_output_acc: 0.8448 - val_emotion_output_acc: 0.7188
# Epoch 18/100
# 360/360 [==============================] - 282s 784ms/step - loss: 5.1001 - gender_output_loss: 0.1779 - image_quality_output_loss: 0.7962 - age_output_loss: 1.0769 - weight_output_loss: 0.7178 - bag_output_loss: 0.5792 - footwear_output_loss: 0.6542 - pose_output_loss: 0.2718 - emotion_output_loss: 0.8261 - gender_output_acc: 0.9309 - image_quality_output_acc: 0.6263 - age_output_acc: 0.5234 - weight_output_acc: 0.7141 - bag_output_acc: 0.7800 - footwear_output_acc: 0.7133 - pose_output_acc: 0.8968 - emotion_output_acc: 0.7158 - val_loss: 6.6771 - val_gender_output_loss: 0.3579 - val_image_quality_output_loss: 1.0157 - val_age_output_loss: 1.3467 - val_weight_output_loss: 0.9494 - val_bag_output_loss: 0.9140 - val_footwear_output_loss: 0.8143 - val_pose_output_loss: 0.4289 - val_emotion_output_loss: 0.8503 - val_gender_output_acc: 0.8916 - val_image_quality_output_acc: 0.5257 - val_age_output_acc: 0.4441 - val_weight_output_acc: 0.6542 - val_bag_output_acc: 0.7051 - val_footwear_output_acc: 0.6623 - val_pose_output_acc: 0.8750 - val_emotion_output_acc: 0.7188
# Epoch 19/100
# 359/360 [============================>.] - ETA: 0s - loss: 4.9552 - gender_output_loss: 0.1574 - image_quality_output_loss: 0.7889 - age_output_loss: 1.0515 - weight_output_loss: 0.6888 - bag_output_loss: 0.5594 - footwear_output_loss: 0.6358 - pose_output_loss: 0.2543 - emotion_output_loss: 0.8191 - gender_output_acc: 0.9413 - image_quality_output_acc: 0.6339 - age_output_acc: 0.5389 - weight_output_acc: 0.7214 - bag_output_acc: 0.7923 - footwear_output_acc: 0.7237 - pose_output_acc: 0.9108 - emotion_output_acc: 0.7155Epoch 19/100
# 360/360 [==============================] - 283s 787ms/step - loss: 4.9562 - gender_output_loss: 0.1577 - image_quality_output_loss: 0.7894 - age_output_loss: 1.0517 - weight_output_loss: 0.6892 - bag_output_loss: 0.5593 - footwear_output_loss: 0.6361 - pose_output_loss: 0.2541 - emotion_output_loss: 0.8188 - gender_output_acc: 0.9410 - image_quality_output_acc: 0.6337 - age_output_acc: 0.5388 - weight_output_acc: 0.7210 - bag_output_acc: 0.7925 - footwear_output_acc: 0.7236 - pose_output_acc: 0.9108 - emotion_output_acc: 0.7157 - val_loss: 6.7347 - val_gender_output_loss: 0.2880 - val_image_quality_output_loss: 1.0354 - val_age_output_loss: 1.3470 - val_weight_output_loss: 0.9766 - val_bag_output_loss: 0.9608 - val_footwear_output_loss: 0.8373 - val_pose_output_loss: 0.4408 - val_emotion_output_loss: 0.8487 - val_gender_output_acc: 0.9113 - val_image_quality_output_acc: 0.5615 - val_age_output_acc: 0.4567 - val_weight_output_acc: 0.6568 - val_bag_output_acc: 0.6885 - val_footwear_output_acc: 0.6568 - val_pose_output_acc: 0.8735 - val_emotion_output_acc: 0.7011
# Epoch 20/100
# 360/360 [==============================] - 284s 789ms/step - loss: 4.9526 - gender_output_loss: 0.1664 - image_quality_output_loss: 0.7787 - age_output_loss: 1.0526 - weight_output_loss: 0.7037 - bag_output_loss: 0.5600 - footwear_output_loss: 0.6253 - pose_output_loss: 0.2443 - emotion_output_loss: 0.8215 - gender_output_acc: 0.9360 - image_quality_output_acc: 0.6375 - age_output_acc: 0.5443 - weight_output_acc: 0.7154 - bag_output_acc: 0.7904 - footwear_output_acc: 0.7305 - pose_output_acc: 0.9076 - emotion_output_acc: 0.7159 - val_loss: 6.8630 - val_gender_output_loss: 0.3364 - val_image_quality_output_loss: 1.0437 - val_age_output_loss: 1.3422 - val_weight_output_loss: 0.9397 - val_bag_output_loss: 1.0175 - val_footwear_output_loss: 0.8833 - val_pose_output_loss: 0.4533 - val_emotion_output_loss: 0.8471 - val_gender_output_acc: 0.9073 - val_image_quality_output_acc: 0.5398 - val_age_output_acc: 0.4546 - val_weight_output_acc: 0.6447 - val_bag_output_acc: 0.6961 - val_footwear_output_acc: 0.6648 - val_pose_output_acc: 0.8715 - val_emotion_output_acc: 0.7213
#
# Epoch 00020: saving model to /content/gdrive/My Drive/person_attributes3.hdf5
# Epoch 21/100
# 134/360 [==========>...................] - ETA: 2:59 - loss: 5.0191 - gender_output_loss: 0.1669 - image_quality_output_loss: 0.7757 - age_output_loss: 1.0518 - weight_output_loss: 0.6928 - bag_output_loss: 0.5645 - footwear_output_loss: 0.6578 - pose_output_loss: 0.2684 - emotion_output_loss: 0.8412 - gender_output_acc: 0.9401 - image_quality_output_acc: 0.6446 - age_output_acc: 0.5396 - weight_output_acc: 0.7162 - bag_output_acc: 0.7871 - footwear_output_acc: 0.7129 - pose_output_acc: 0.8990 - emotion_output_acc: 0.7092
# Process ForkPoolWorker-249:
# Process ForkPoolWorker-252:
# Process ForkPoolWorker-248:
# Process ForkPoolWorker-247:
# Process ForkPoolWorker-251:
# Process ForkPoolWorker-242:
# Process ForkPoolWorker-250:
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/usr/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
# Traceback (most recent call last):
#   File "/usr/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
# Process ForkPoolWorker-241:
#   File "/usr/lib/python3.6/multiprocessing/pool.py", line 108, in worker
#     task = get()
#   File "/usr/lib/python3.6/multiprocessing/pool.py", line 108, in worker
#     task = get()
#   File "/usr/lib/python3.6/multiprocessing/pool.py", line 108, in worker
#     task = get()
#   File "/usr/lib/python3.6/multiprocessing/queues.py", line 334, in get
#     with self._rlock:
#   File "/usr/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.6/multiprocessing/queues.py", line 334, in get
#     with self._rlock:
#   File "/usr/lib/python3.6/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/usr/lib/python3.6/multiprocessing/queues.py", line 334, in get
#     with self._rlock:
#   File "/usr/lib/python3.6/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/usr/lib/python3.6/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
# KeyboardInterrupt
#   File "/usr/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.6/multiprocessing/pool.py", line 108, in worker
#     task = get()
#   File "/usr/lib/python3.6/multiprocessing/pool.py", line 108, in worker
#     task = get()
# KeyboardInterrupt
# Traceback (most recent call last):
# KeyboardInterrupt
#   File "/usr/lib/python3.6/multiprocessing/queues.py", line 335, in get
#     res = self._reader.recv_bytes()
#   File "/usr/lib/python3.6/multiprocessing/queues.py", line 334, in get
#     with self._rlock:
#   File "/usr/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.6/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
# KeyboardInterrupt
#   File "/usr/lib/python3.6/multiprocessing/connection.py", line 216, in recv_bytes
#     buf = self._recv_bytes(maxlength)
#   File "/usr/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
# Traceback (most recent call last):
#   File "/usr/lib/python3.6/multiprocessing/connection.py", line 407, in _recv_bytes
#     buf = self._recv(4)
#   File "/usr/lib/python3.6/multiprocessing/pool.py", line 108, in worker
#     task = get()
#   File "/usr/lib/python3.6/multiprocessing/queues.py", line 334, in get
#     with self._rlock:
#   File "/usr/lib/python3.6/multiprocessing/connection.py", line 379, in _recv
#     chunk = read(handle, remaining)
# KeyboardInterrupt
#   File "/usr/lib/python3.6/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/usr/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
# KeyboardInterrupt
#   File "/usr/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.6/multiprocessing/pool.py", line 108, in worker
#     task = get()
#   File "/usr/lib/python3.6/multiprocessing/queues.py", line 335, in get
#     res = self._reader.recv_bytes()
#   File "/usr/lib/python3.6/multiprocessing/connection.py", line 216, in recv_bytes
#     buf = self._recv_bytes(maxlength)
#   File "/usr/lib/python3.6/multiprocessing/connection.py", line 407, in _recv_bytes
#     buf = self._recv(4)
# Process ForkPoolWorker-246:
#   File "/usr/lib/python3.6/multiprocessing/connection.py", line 379, in _recv
#     chunk = read(handle, remaining)
# KeyboardInterrupt
# Traceback (most recent call last):
# Process ForkPoolWorker-245:
# Process ForkPoolWorker-243:
# Traceback (most recent call last):
#   File "/usr/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/usr/lib/python3.6/multiprocessing/pool.py", line 119, in worker
#     result = (True, func(*args, **kwds))
#   File "/usr/lib/python3.6/multiprocessing/pool.py", line 119, in worker
#     result = (True, func(*args, **kwds))
#   File "/usr/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/usr/local/lib/python3.6/dist-packages/keras/utils/data_utils.py", line 406, in get_index
#     return _SHARED_SEQUENCES[uid][i]
#   File "/usr/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-10-8643e8fefbb2>", line 42, in __getitem__
#     image = augmentor(image)
#   File "/usr/local/lib/python3.6/dist-packages/keras/utils/data_utils.py", line 406, in get_index
#     return _SHARED_SEQUENCES[uid][i]
#   File "/usr/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.6/multiprocessing/pool.py", line 119, in worker
#     result = (True, func(*args, **kwds))
# Process ForkPoolWorker-244:
#   File "<ipython-input-7-c08892e5d4ec>", line 80, in augmentor
#     return seq.augment_images(images)
#   File "/usr/lib/python3.6/multiprocessing/pool.py", line 119, in worker
#     result = (True, func(*args, **kwds))
#   File "/usr/local/lib/python3.6/dist-packages/imgaug/augmenters/meta.py", line 603, in augment_images
#     hooks=hooks
#   File "<ipython-input-10-8643e8fefbb2>", line 42, in __getitem__
#     image = augmentor(image)
#   File "/usr/local/lib/python3.6/dist-packages/keras/utils/data_utils.py", line 406, in get_index
#     return _SHARED_SEQUENCES[uid][i]
#   File "/usr/local/lib/python3.6/dist-packages/keras/utils/data_utils.py", line 406, in get_index
#     return _SHARED_SEQUENCES[uid][i]
#   File "/usr/local/lib/python3.6/dist-packages/imgaug/augmenters/meta.py", line 2816, in _augment_images
#     hooks=hooks
#   File "<ipython-input-7-c08892e5d4ec>", line 80, in augmentor
#     return seq.augment_images(images)
#   File "<ipython-input-10-8643e8fefbb2>", line 42, in __getitem__
#     image = augmentor(image)
#   File "<ipython-input-10-8643e8fefbb2>", line 42, in __getitem__
#     image = augmentor(image)
#   File "/usr/local/lib/python3.6/dist-packages/imgaug/augmenters/meta.py", line 515, in augment_images
#     hooks=hooks
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/dist-packages/imgaug/augmenters/meta.py", line 603, in augment_images
#     hooks=hooks
#   File "<ipython-input-7-c08892e5d4ec>", line 80, in augmentor
#     return seq.augment_images(images)
#   File "/usr/local/lib/python3.6/dist-packages/imgaug/augmenters/meta.py", line 3118, in _augment_images
#     hooks=hooks
#   File "<ipython-input-7-c08892e5d4ec>", line 80, in augmentor
#     return seq.augment_images(images)
#   File "/usr/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/usr/local/lib/python3.6/dist-packages/imgaug/augmenters/meta.py", line 603, in augment_images
#     hooks=hooks
#   File "/usr/local/lib/python3.6/dist-packages/imgaug/augmenters/meta.py", line 515, in augment_images
#     hooks=hooks
#   File "/usr/local/lib/python3.6/dist-packages/imgaug/augmenters/meta.py", line 2816, in _augment_images
#     hooks=hooks
#   File "/usr/local/lib/python3.6/dist-packages/imgaug/augmenters/meta.py", line 603, in augment_images
#     hooks=hooks
#   File "/usr/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/local/lib/python3.6/dist-packages/imgaug/augmenters/meta.py", line 515, in augment_images
#     hooks=hooks
#   File "/usr/local/lib/python3.6/dist-packages/imgaug/augmenters/meta.py", line 2816, in _augment_images
#     hooks=hooks
#   File "/usr/local/lib/python3.6/dist-packages/imgaug/augmenters/meta.py", line 3386, in _augment_images
#     hooks=hooks
#   File "/usr/lib/python3.6/multiprocessing/pool.py", line 119, in worker
#     result = (True, func(*args, **kwds))
#   File "/usr/local/lib/python3.6/dist-packages/imgaug/augmenters/meta.py", line 2816, in _augment_images
#     hooks=hooks
#   File "/usr/local/lib/python3.6/dist-packages/imgaug/augmenters/meta.py", line 515, in augment_images
#     hooks=hooks
#   File "/usr/local/lib/python3.6/dist-packages/imgaug/augmenters/meta.py", line 515, in augment_images
#     hooks=hooks
#   File "/usr/local/lib/python3.6/dist-packages/imgaug/augmenters/meta.py", line 3118, in _augment_images
#     hooks=hooks
#   File "/usr/local/lib/python3.6/dist-packages/keras/utils/data_utils.py", line 406, in get_index
#     return _SHARED_SEQUENCES[uid][i]
#   File "/usr/local/lib/python3.6/dist-packages/imgaug/augmenters/meta.py", line 515, in augment_images
#     hooks=hooks
#   File "/usr/local/lib/python3.6/dist-packages/imgaug/augmenters/meta.py", line 3118, in _augment_images
#     hooks=hooks
#   File "/usr/local/lib/python3.6/dist-packages/imgaug/augmenters/meta.py", line 515, in augment_images
#     hooks=hooks
#   File "/usr/local/lib/python3.6/dist-packages/imgaug/augmenters/meta.py", line 2823, in _augment_images
#     hooks=hooks
#   File "/usr/local/lib/python3.6/dist-packages/imgaug/augmenters/meta.py", line 3118, in _augment_images
#     hooks=hooks
#   File "<ipython-input-10-8643e8fefbb2>", line 42, in __getitem__
#     image = augmentor(image)
#   File "/usr/local/lib/python3.6/dist-packages/imgaug/augmenters/meta.py", line 515, in augment_images
#     hooks=hooks
#   File "/usr/local/lib/python3.6/dist-packages/imgaug/augmenters/meta.py", line 3386, in _augment_images
#     hooks=hooks
#   File "/usr/local/lib/python3.6/dist-packages/imgaug/augmenters/meta.py", line 513, in augment_images
#     random_state=ia.copy_random_state(self.random_state),
#   File "/usr/local/lib/python3.6/dist-packages/imgaug/augmenters/meta.py", line 515, in augment_images
#     hooks=hooks
#   File "/usr/local/lib/python3.6/dist-packages/imgaug/augmenters/blend.py", line 640, in _augment_images
#     alphas = self.factor.draw_samples((h, w), random_state=ia.new_random_state(seeds[i]))
#   File "/usr/local/lib/python3.6/dist-packages/imgaug/augmenters/meta.py", line 515, in augment_images
#     hooks=hooks
#   File "/usr/local/lib/python3.6/dist-packages/imgaug/imgaug.py", line 402, in copy_random_state
#     rs_copy = dummy_random_state()
#   File "/usr/local/lib/python3.6/dist-packages/imgaug/augmenters/geometric.py", line 1795, in _augment_images
#     output_shape=images[i].shape
#   File "<ipython-input-7-c08892e5d4ec>", line 80, in augmentor
#     return seq.augment_images(images)
#   File "/usr/local/lib/python3.6/dist-packages/skimage/transform/_warps.py", line 906, in warp
#     coords = warp_coords(coord_map, output_shape)
#   File "/usr/local/lib/python3.6/dist-packages/imgaug/parameters.py", line 288, in draw_samples
#     random_state)
#   File "/usr/local/lib/python3.6/dist-packages/imgaug/augmenters/meta.py", line 2823, in _augment_images
#     hooks=hooks
#   File "/usr/local/lib/python3.6/dist-packages/imgaug/augmenters/meta.py", line 603, in augment_images
#     hooks=hooks
#   File "/usr/local/lib/python3.6/dist-packages/imgaug/imgaug.py", line 376, in dummy_random_state
#     return np.random.RandomState(1)
#   File "/usr/local/lib/python3.6/dist-packages/skimage/transform/_warps.py", line 613, in warp_coords
#     tf_coords = coord_map(tf_coords)
#   File "/usr/local/lib/python3.6/dist-packages/imgaug/parameters.py", line 2085, in _draw_samples
#     noise_iter = self.other_param.draw_samples(size, random_state=ia.new_random_state(seed+2+i))
#   File "/usr/local/lib/python3.6/dist-packages/imgaug/augmenters/meta.py", line 2816, in _augment_images
#     hooks=hooks
#   File "/usr/local/lib/python3.6/dist-packages/skimage/transform/_warps.py", line 897, in coord_map
#     return inverse_map(*args, **map_args)
#   File "mtrand.pyx", line 101, in numpy.random.mtrand.RandomState.__init__
#   File "/usr/local/lib/python3.6/dist-packages/imgaug/augmenters/meta.py", line 515, in augment_images
#     hooks=hooks
#   File "/usr/local/lib/python3.6/dist-packages/imgaug/parameters.py", line 288, in draw_samples
#     random_state)
#   File "/usr/local/lib/python3.6/dist-packages/skimage/transform/_geometric.py", line 890, in __call__
#     simplex = self._tesselation.find_simplex(coords)
#   File "/usr/local/lib/python3.6/dist-packages/imgaug/augmenters/meta.py", line 515, in augment_images
#     hooks=hooks
#   File "mt19937.pyx", line 130, in numpy.random.mt19937.MT19937.__init__
#   File "/usr/local/lib/python3.6/dist-packages/imgaug/parameters.py", line 2298, in _draw_samples
#     noise_iter = self._draw_samples_iteration(h, w, seed + 10 + i, upscale_methods[i])
#   File "/usr/local/lib/python3.6/dist-packages/imgaug/augmenters/segmentation.py", line 191, in _augment_images
#     segments = segmentation.slic(image, n_segments=n_segments_samples[i], compactness=10)
# KeyboardInterrupt
#   File "bit_generator.pyx", line 520, in numpy.random.bit_generator.BitGenerator.__init__
#   File "/usr/local/lib/python3.6/dist-packages/imgaug/augmenters/meta.py", line 3118, in _augment_images
#     hooks=hooks
#   File "/usr/local/lib/python3.6/dist-packages/skimage/segmentation/slic_superpixels.py", line 144, in slic
#     image = rgb2lab(image)
#   File "/usr/local/lib/python3.6/dist-packages/imgaug/parameters.py", line 2346, in _draw_samples_iteration
#     noise_0to1 = ia.imresize_single_image(noise_0to1_3d, (h, w), interpolation=upscale_method)
#   File "/usr/local/lib/python3.6/dist-packages/skimage/color/colorconv.py", line 1038, in rgb2lab
#     return xyz2lab(rgb2xyz(rgb), illuminant, observer)
#   File "/usr/local/lib/python3.6/dist-packages/imgaug/augmenters/meta.py", line 515, in augment_images
#     hooks=hooks
#   File "bit_generator.pyx", line 318, in numpy.random.bit_generator.SeedSequence.__init__
#   File "/usr/local/lib/python3.6/dist-packages/imgaug/imgaug.py", line 1289, in imresize_single_image
#     rs = imresize_many_images(image[np.newaxis, :, :, :], sizes, interpolation=interpolation)
#   File "/usr/local/lib/python3.6/dist-packages/imgaug/augmenters/meta.py", line 3386, in _augment_images
#     hooks=hooks
#   File "/usr/local/lib/python3.6/dist-packages/skimage/color/colorconv.py", line 683, in rgb2xyz
#     arr[mask] = np.power((arr[mask] + 0.055) / 1.055, 2.4)
#   File "bit_generator.pyx", line 394, in numpy.random.bit_generator.SeedSequence.get_assembled_entropy
#   File "/usr/local/lib/python3.6/dist-packages/imgaug/imgaug.py", line 1235, in imresize_many_images
#     result_img = cv2.resize(image, (width, height), interpolation=ip)
#   File "/usr/local/lib/python3.6/dist-packages/imgaug/augmenters/meta.py", line 515, in augment_images
#     hooks=hooks
# KeyboardInterrupt
#   File "<__array_function__ internals>", line 2, in concatenate
# KeyboardInterrupt
# KeyboardInterrupt
#   File "/usr/local/lib/python3.6/dist-packages/imgaug/augmenters/meta.py", line 2823, in _augment_images
#     hooks=hooks
#   File "/usr/local/lib/python3.6/dist-packages/imgaug/augmenters/meta.py", line 515, in augment_images
#     hooks=hooks
#   File "/usr/local/lib/python3.6/dist-packages/imgaug/augmenters/geometric.py", line 1795, in _augment_images
#     output_shape=images[i].shape
#   File "/usr/local/lib/python3.6/dist-packages/skimage/transform/_warps.py", line 913, in warp
#     mode=ndi_mode, order=order, cval=cval)
#   File "/usr/local/lib/python3.6/dist-packages/scipy/ndimage/interpolation.py", line 350, in map_coordinates
#     output, order, mode, cval, None, None)
# KeyboardInterrupt
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-22-da5bc2a1f4f1> in <module>()
#      15     workers=6,
#      16     epochs=100,
# ---> 17     verbose=1,callbacks=callbacks
#      18 )
#
# /usr/local/lib/python3.6/dist-packages/keras/legacy/interfaces.py in wrapper(*args, **kwargs)
#      89                 warnings.warn('Update your `' + object_name + '` call to the ' +
#      90                               'Keras 2 API: ' + signature, stacklevel=2)
# ---> 91             return func(*args, **kwargs)
#      92         wrapper._original_function = func
#      93         return wrapper
#
# /usr/local/lib/python3.6/dist-packages/keras/engine/training.py in fit_generator(self, generator, steps_per_epoch, epochs, verbose, callbacks, validation_data, validation_steps, validation_freq, class_weight, max_queue_size, workers, use_multiprocessing, shuffle, initial_epoch)
#    1656             use_multiprocessing=use_multiprocessing,
#    1657             shuffle=shuffle,
# -> 1658             initial_epoch=initial_epoch)
#    1659
#    1660     @interfaces.legacy_generator_methods_support
#
# /usr/local/lib/python3.6/dist-packages/keras/engine/training_generator.py in fit_generator(model, generator, steps_per_epoch, epochs, verbose, callbacks, validation_data, validation_steps, validation_freq, class_weight, max_queue_size, workers, use_multiprocessing, shuffle, initial_epoch)
#     213                 outs = model.train_on_batch(x, y,
#     214                                             sample_weight=sample_weight,
# --> 215                                             class_weight=class_weight)
#     216
#     217                 outs = to_list(outs)
#
# /usr/local/lib/python3.6/dist-packages/keras/engine/training.py in train_on_batch(self, x, y, sample_weight, class_weight)
#    1447             ins = x + y + sample_weights
#    1448         self._make_train_function()
# -> 1449         outputs = self.train_function(ins)
#    1450         return unpack_singleton(outputs)
#    1451
#
# /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py in __call__(self, inputs)
#    2977                     return self._legacy_call(inputs)
#    2978
# -> 2979             return self._call(inputs)
#    2980         else:
#    2981             if py_any(is_tensor(x) for x in inputs):
#
# /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py in _call(self, inputs)
#    2935             fetched = self._callable_fn(*array_vals, run_metadata=self.run_metadata)
#    2936         else:
# -> 2937             fetched = self._callable_fn(*array_vals)
#    2938         return fetched[:len(self.outputs)]
#    2939
#
# /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/client/session.py in __call__(self, *args, **kwargs)
#    1470         ret = tf_session.TF_SessionRunCallable(self._session._session,
#    1471                                                self._handle, args,
# -> 1472                                                run_metadata_ptr)
#    1473         if run_metadata:
#    1474           proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# KeyboardInterrupt:

# %%
results = model.evaluate_generator(valid_gen,verbose=1)
dict(zip(model.metrics_names, results))
# Out:
# 31/31 [==============================] - 24s 787ms/step
# {'age_output_acc': 0.45413306451612906,
#  'age_output_loss': 1.2633996471281974,
#  'bag_output_acc': 0.6804435483870968,
#  'bag_output_loss': 0.8027199679805387,
#  'emotion_output_acc': 0.7232862903225806,
#  'emotion_output_loss': 0.8459457159042358,
#  'footwear_output_acc': 0.6587701612903226,
#  'footwear_output_loss': 0.7830503679090931,
#  'gender_output_acc': 0.8986895161290323,
#  'gender_output_loss': 0.2588314863462602,
#  'image_quality_output_acc': 0.5141129032258065,
#  'image_quality_output_loss': 1.06295233772647,
#  'loss': 6.30742552972609,
#  'pose_output_acc': 0.859375,
#  'pose_output_loss': 0.40888252229459826,
#  'weight_output_acc': 0.6607862903225806,
#  'weight_output_loss': 0.8816434990975165}
